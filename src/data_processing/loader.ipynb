# %% [markdown]
# # Data exploration

# %% [markdown]
# ## statistic

# %%
import pandas as pd
from settings import Data, FL_config
import os

# %%
data_statistic = pd.read_csv(os.path.join(Data.get_data_path(),'data_statistic.csv'))
data_statistic
# Out:
#                      Key          Value
# 0          Total samples  893731.000000
# 1          Total classes     180.000000
# 2   Max words per sample      89.000000
# 3  Mean words per sample      12.290619
# 4   Std words per sample       6.912577

# %% [markdown]
# # Get loader

# %%
from loader import get_loader
from settings import Data, strategies
import os
import random

# %%
def get_random_file(strategy:str, is_train:bool) -> str:
    if is_train:
        data_path = os.path.join(Data.get_data_path(), f'{strategy}_client_train')
    else:
        sub_dir = "query" if random.uniform(0,1) else "support"
        data_path = os.path.join(Data.get_data_path(), f'{strategy}_client_test', sub_dir)

    all_files = os.listdir(data_path)

    # Check if there are any files in the directory
    if not all_files:
        return None

    # Choose a random file from the list
    random_file = random.choice(all_files)

    # Return the full path to the random file
    return os.path.join(data_path, random_file)

# %%
data_loader = get_loader(
    file_path=get_random_file(strategies.DISTRIBUTION_BASED_SKEW, True),
    batch_size=32,
    shuffle=True,
    split_supp_query=False
)
for batch in data_loader:
    print(type(batch['targets']))
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# ...
